# %%
import AA500
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Recovery Experiments

# %%
data_dir = '/Users/beneck/Library/CloudStorage/OneDrive-NortheasternUniversity/Boise Project/Data/Reynolds Nitrate Monitoring/Nutrient Analyzer Data/'
result_dir = data_dir + '20251022 Run/'

# %%
recovery_result = AA500.AA500_Result(result_dir + 'RCEW_NOx-PO4-NH3_22Oct25R1.txt', result_dir+'samplelist_20251022.xlsx',data_dir + 'Master Sample Sheet.xlsx')

# %%
# select mean, std, and QA columns for Phosphate and Ammonium
cols = [f"{analyte} {suffix}" for analyte in ['Phosphate', 'Ammonium'] for suffix in ['mean', 'std', 'QA']]
recovery_result.result_df[cols]

# %%
recovery_result.result_df

# %%
recovery_result.recovery_styled

# %% [markdown]
# - all nitrate and ammonium recoveries look good except sample 211 - that looks like I added two drops of standard by accident
# - phosphtae 221, 228, 225, and 262 look bad... why?
# - note: all bad phosphate recoveries also had bad peaks, which is good - they are identifiable!
