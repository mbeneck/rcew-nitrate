# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/Users/beneck/Library/CloudStorage/OneDrive-NortheasternUniversity/Boise Project/Data/SCAN Data Usage Experiment/2024-07-17_00-03-58.fp", sep='\t', header=1).drop('Status_0', axis=1)
df
# Out:
#                 Date/Time  200.00  202.50  205.00  207.50  210.00  212.50  \
# 0    2024.07.17  00:03:58     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2024.07.17  00:18:58     NaN     NaN     NaN     NaN     NaN     NaN
# 2    2024.07.17  00:33:58     NaN     NaN     NaN     NaN     NaN     NaN
# 3    2024.07.17  00:48:58     NaN     NaN     NaN     NaN     NaN     NaN
# 4    2024.07.17  01:03:58     NaN     NaN     NaN     NaN     NaN     NaN
# ..                    ...     ...     ...     ...     ...     ...     ...
# 814  2024.07.25  11:33:58     NaN     NaN     NaN     NaN     NaN     NaN
# 815  2024.07.25  11:48:58     NaN     NaN     NaN     NaN     NaN     NaN
# 816  2024.07.25  12:03:58     NaN     NaN     NaN     NaN     NaN     NaN
# 817  2024.07.25  12:18:58     NaN     NaN     NaN     NaN     NaN     NaN
# 818  2024.07.25  12:33:58     NaN     NaN     NaN     NaN     NaN     NaN
#
#      215.00  217.50  220.00  ...  727.50  730.00  732.50  735.00  737.50  \
# ...

# %%
filesize= os.path.getsize("/Users/beneck/Library/CloudStorage/OneDrive-NortheasternUniversity/Boise Project/Data/SCAN Data Usage Experiment/2024-07-17_00-03-58.fp")
filesize
# Out:
# 1303960

# %%
kb_per_row = filesize/1000/df.index.size
kb_per_row
# Out:
# 1.5921367521367522

# %%
max_filesize = 2000

data_points_for_maxfile = max_filesize/kb_per_row
data_points_for_maxfile
# Out:
# 1256.1735022546704

# %% [markdown]
# # 30s logging interval, ran for just under 24h
# - max filesize upped to 4MB from 2MB on S::CAN

# %%
df2 = pd.read_csv("/Users/beneck/Library/CloudStorage/OneDrive-NortheasternUniversity/Boise Project/Data/SCAN Data Usage Experiment/2024-07-31_00-03-58.fp", sep='\t', header=1).drop('Status_0', axis=1)
df2
# Out:
#                  Date/Time  200.00  202.50  205.00  207.50  210.00  212.50  \
# 0     2024.07.17  00:03:58     NaN     NaN     NaN     NaN     NaN     NaN
# 1     2024.07.17  00:18:58     NaN     NaN     NaN     NaN     NaN     NaN
# 2     2024.07.17  00:33:58     NaN     NaN     NaN     NaN     NaN     NaN
# 3     2024.07.17  00:48:58     NaN     NaN     NaN     NaN     NaN     NaN
# 4     2024.07.17  01:03:58     NaN     NaN     NaN     NaN     NaN     NaN
# ...                    ...     ...     ...     ...     ...     ...     ...
# 1515  2024.07.31  01:30:23     NaN     NaN     NaN     NaN     NaN     NaN
# 1516  2024.07.31  01:31:23     NaN     NaN     NaN     NaN     NaN     NaN
# 1517  2024.07.31  01:32:23     NaN     NaN     NaN     NaN     NaN     NaN
# 1518  2024.07.31  01:33:23     NaN     NaN     NaN     NaN     NaN     NaN
# 1519  2024.07.31  01:34:23     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
df2['Timestamp'] = pd.to_datetime(df2['Date/Time'])
df2.set_index('Timestamp', inplace=True)

# %%
df2.loc['07-30-2024 00:00':'07-31-2024 23:59']
# Out:
#                                 Date/Time  200.00  202.50  205.00  207.50  \
# Timestamp
# 2024-07-30 14:13:06  2024.07.30  14:13:06     NaN     NaN     NaN     NaN
# 2024-07-30 14:18:53  2024.07.30  14:18:53     NaN     NaN     NaN     NaN
# 2024-07-30 14:19:53  2024.07.30  14:19:53     NaN     NaN     NaN     NaN
# 2024-07-30 14:20:53  2024.07.30  14:20:53     NaN     NaN     NaN     NaN
# 2024-07-30 14:21:53  2024.07.30  14:21:53     NaN     NaN     NaN     NaN
# ...                                   ...     ...     ...     ...     ...
# 2024-07-31 01:30:23  2024.07.31  01:30:23     NaN     NaN     NaN     NaN
# 2024-07-31 01:31:23  2024.07.31  01:31:23     NaN     NaN     NaN     NaN
# 2024-07-31 01:32:23  2024.07.31  01:32:23     NaN     NaN     NaN     NaN
# 2024-07-31 01:33:23  2024.07.31  01:33:23     NaN     NaN     NaN     NaN
# 2024-07-31 01:34:23  2024.07.31  01:34:23     NaN     NaN     NaN     NaN
#
# ...

# %%
filesize2= os.path.getsize("/Users/beneck/Library/CloudStorage/OneDrive-NortheasternUniversity/Boise Project/Data/SCAN Data Usage Experiment/2024-07-31_00-03-58.fp")
filesize2
# Out:
# 2418905

# %%
kb_per_row2 = filesize2/1000/df2.index.size
kb_per_row2
# Out:
# 1.5913848684210528

# %% [markdown]
# - ok, so seems like the limit is 1520 rows.
# - but the file didn't clear all the way - more than half of it is from the last experiment
# - so maybe it is possible to up the limit but I'm just going to assume it isn't and set the mneter back to what it was
